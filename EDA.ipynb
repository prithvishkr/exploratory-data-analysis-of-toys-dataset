# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# gender-
# male - 0
# female - 1
# illness-
# no - 0
# yes- 1
#
# income-
# >50K = 1
# <=50k = 0

# %%
data=pd.read_csv('toy_dataset.csv')
data
# Out:
#         Number    City  Gender  Age  Income  Illness
# 0            1  Dallas       0   41       0        0
# 1            2  Dallas       0   54       0        0
# 2            3  Dallas       0   42       1        0
# 3            4  Dallas       0   40       1        0
# 4            5  Dallas       0   46       0        0
# 5            6  Dallas       1   36       0        0
# 6            7  Dallas       1   32       0        0
# 7            8  Dallas       0   39       1        0
# 8            9  Dallas       0   51       0        0
# 9           10  Dallas       1   30       0        0
# 10          11  Dallas       1   48       1        1
# 11          12  Dallas       0   47       0        0
# 12          13  Dallas       0   46       0        0
# 13          14  Dallas       1   42       0        0
# 14          15  Dallas       1   61       1        0
# 15          16  Dallas       0   43       1        0
# 16          17  Dallas       0   27       0        0
# ...

# %%
data.describe()
# Out:
#               Number         Gender            Age         Income  \
# count  150000.000000  150000.000000  150000.000000  150000.000000
# mean    75000.500000       0.441333      44.950200       0.239233
# std     43301.414527       0.496548      11.572486       0.426617
# min         1.000000       0.000000      25.000000       0.000000
# 25%     37500.750000       0.000000      35.000000       0.000000
# 50%     75000.500000       0.000000      45.000000       0.000000
# 75%    112500.250000       1.000000      55.000000       0.000000
# max    150000.000000       1.000000      65.000000       1.000000
#
#              Illness
# count  150000.000000
# mean        0.080927
# std         0.272723
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 6 columns):
# Number     150000 non-null int64
# City       150000 non-null object
# Gender     150000 non-null int64
# Age        150000 non-null int64
# Income     150000 non-null int64
# Illness    150000 non-null int64
# dtypes: int64(5), object(1)
# memory usage: 6.9+ MB

# %%
min_data=data.min(skipna=False)
min_data
# Out:
# Number          1
# City       Austin
# Gender          0
# Age            25
# Income          0
# Illness         0
# dtype: object

# %%
max_data=data.max(skipna=False)
max_data
# Out:
# Number              150000
# City       Washington D.C.
# Gender                   1
# Age                     65
# Income                   1
# Illness                  1
# dtype: object

# %% [markdown]
# # This is used to check binary data such as gender and illness using bar plot

# %%
def bar_plot(variable):
    var = data[variable]
    varValue = var.value_counts()
   
    #visualize
    plt.figure(figsize = (9,3))
    plt.bar(varValue.index, varValue)
    plt.xticks(varValue.index, varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable, varValue))

# %%
category1= ["Gender"]

# %%
for c in category1:
    bar_plot(c)
# Out:
# Gender:
#  0    83800
# 1    66200
# Name: Gender, dtype: int64

# %%
c2=["Illness"]
for c in c2:
    bar_plot(c)
# Out:
# Illness:
#  0    137861
# 1     12139
# Name: Illness, dtype: int64

# %%
c2=["Income"]
for c in c2:
    bar_plot(c)
# Out:
# Income:
#  0    114115
# 1     35885
# Name: Income, dtype: int64

# %% [markdown]
# # This is to check frequency of variable VS variable using Histogram

# %%
def plot_hist(variable):
    plt.figure(figsize =(9,3))
    plt.hist(data[variable], bins =50)
    plt.xlabel(variable)
    plt.ylabel("Frequency")
    plt.title("{} distribution with hist".format(variable))
    plt.show()

# %%
numericVar = ["Age"]
for n in numericVar:
    plot_hist(n)

# %%
numericVar = ["Illness"]
for n in numericVar:
    plot_hist(n)

# %%
numericVar = ["Income"]
for n in numericVar:
    plot_hist(n)

# %% [markdown]
# # This is used to compare diffrent fields with other fields to understand their relation

# %%
data[["Age", "Illness"]].groupby(["Age"], as_index = False).mean().sort_values(by = "Illness", ascending = False)
# Out:
#     Age   Illness
# 10   35  0.092400
# 18   43  0.089591
# 25   50  0.089382
# 24   49  0.089314
# 37   62  0.088219
# 17   42  0.086170
# 22   47  0.085873
# 36   61  0.085630
# 30   55  0.085435
# 15   40  0.084225
# 32   57  0.084137
# 28   53  0.082707
# 21   46  0.082547
# 4    29  0.082523
# 39   64  0.082495
# 2    27  0.082322
# 0    25  0.081906
# 1    26  0.081164
# 7    32  0.081139
# 13   38  0.080611
# 16   41  0.080528
# 27   52  0.080469
# 26   51  0.080451
# 8    33  0.080393
# 35   60  0.080123
# 38   63  0.080074
# 6    31  0.079755
# 14   39  0.079456
# 9    34  0.078437
# 40   65  0.077790
# 19   44  0.077737
# 11   36  0.076984
# 3    28  0.076883
# 34   59  0.076556
# 33   58  0.076555
# 12   37  0.075577
# 31   56  0.075236
# 23   48  0.074272
# 29   54  0.073215
# 5    30  0.069686
# 20   45  0.068937

# %%
data[["Gender", "Illness"]].groupby(["Gender"], as_index = False).mean().sort_values(by = "Illness", ascending = False)
# Out:
#    Gender   Illness
# 0       0  0.081241
# 1       1  0.080529

# %%
data[["City", "Illness"]].groupby(["City"], as_index = False).mean().sort_values(by = "Illness", ascending = False)
# Out:
#               City   Illness
# 4    Mountain View  0.082847
# 1           Boston  0.082641
# 7  Washington D.C.  0.082266
# 0           Austin  0.082249
# 2           Dallas  0.081849
# 6        San Diego  0.080721
# 5    New York City  0.079929
# 3      Los Angeles  0.079818

# %%
data[["City", "Gender"]].groupby(["City"], as_index = False).mean().sort_values(by = "Gender", ascending = False)
# Out:
#               City    Gender
# 1           Boston  0.447536
# 3      Los Angeles  0.444006
# 2           Dallas  0.441721
# 4    Mountain View  0.441381
# 5    New York City  0.440734
# 7  Washington D.C.  0.438916
# 0           Austin  0.438090
# 6        San Diego  0.429830

# %%
data[["City", "Income"]].groupby(["City"], as_index = False).mean().sort_values(by = "Income", ascending = False)
# Out:
#               City    Income
# 0           Austin  0.244305
# 7  Washington D.C.  0.239901
# 3      Los Angeles  0.239673
# 4    Mountain View  0.239046
# 5    New York City  0.238993
# 2           Dallas  0.238342
# 6        San Diego  0.238066
# 1           Boston  0.233948

# %%
data[["Gender", "Income"]].groupby(["Gender"], as_index = False).mean().sort_values(by = "Income", ascending = False)
# Out:
#    Gender    Income
# 0       0  0.239475
# 1       1  0.238927

# %%
data[["Age", "Income"]].groupby(["Age"], as_index = False).mean().sort_values(by = "Income", ascending = True)
# Out:
#     Age    Income
# 19   44  0.220518
# 39   64  0.230214
# 7    32  0.230646
# 21   46  0.231454
# 37   62  0.231813
# 15   40  0.232353
# 12   37  0.232564
# 33   58  0.232589
# 24   49  0.233386
# 34   59  0.233642
# 6    31  0.235263
# 9    34  0.235310
# 3    28  0.235387
# 18   43  0.235888
# 14   39  0.236190
# 20   45  0.236512
# 0    25  0.237152
# 27   52  0.237410
# 25   50  0.238624
# 10   35  0.238655
# 22   47  0.238802
# 5    30  0.238810
# 31   56  0.239034
# 38   63  0.239958
# 23   48  0.240449
# 26   51  0.241352
# 40   65  0.241416
# 36   61  0.241638
# 1    26  0.241705
# 2    27  0.241953
# 4    29  0.242313
# 11   36  0.242593
# 16   41  0.243397
# 32   57  0.244373
# 13   38  0.246385
# 28   53  0.246509
# 8    33  0.247280
# 29   54  0.249349
# 35   60  0.254048
# 17   42  0.255851
# 30   55  0.256577

# %%
data[["Income", "Illness"]].groupby(["Income"], as_index = False).mean().sort_values(by = "Illness", ascending = False)
# Out:
#    Income   Illness
# 1       1  0.081120
# 0       0  0.080866

# %% [markdown]
# # Missing Values

# %%
data_len = len(data) 
data = pd.concat([data, data], axis = 0).reset_index(drop = True)

# %%
data.head()
# Out:
#    Number    City  Gender  Age  Income  Illness
# 0       1  Dallas       0   41       0        0
# 1       2  Dallas       0   54       0        0
# 2       3  Dallas       0   42       1        0
# 3       4  Dallas       0   40       1        0
# 4       5  Dallas       0   46       0        0

# %%
data.columns[data.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
data.isnull().sum()
# Out:
# Number     0
# City       0
# Gender     0
# Age        0
# Income     0
# Illness    0
# dtype: int64

# %%
data.columns[data.isnull().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# # Let us visualize this data

# %%
data=data[{'Age','Gender','Income','Illness','City'}].corr()
data
# Out:
#            Gender       Age   Illness    Income
# Gender   1.000000  0.003653 -0.001297 -0.000637
# Age      0.003653  1.000000  0.001811  0.001093
# Illness -0.001297  0.001811  1.000000  0.000398
# Income  -0.000637  0.001093  0.000398  1.000000

# %%
list1=["Illness", "Gender", "Age", "Income"]

# %%
sns.heatmap(data[list1].corr(), annot=True, fmt =".2f")
plt.show()

# %%
a = sns.factorplot(x="Gender", y="Illness", data=data, kind="bar", size =7)
a.set_ylabels("Probability of certain Gender to get sick")
plt.show()
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
a = sns.factorplot(x="Income", y="Illness", data=data, kind="bar", size =10)
a.set_ylabels("Probability of certain Income Group to get sick")
plt.show()

# %%
a = sns.factorplot(x="Age", y="Illness", data=data, kind="bar", size =10)
a.set_ylabels("Probability of certain Income Group to get sick")
plt.show()

# %%
a=sns.FacetGrid(data, col="Illness")
a.map(sns.distplot, "Income", bins=25)
plt.show()
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\numpy\core\_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\lenovo\Anaconda3\lib\site-packages\numpy\core\_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\lenovo\Anaconda3\lib\site-packages\numpy\core\_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\lenovo\Anaconda3\lib\site-packages\numpy\core\_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\lenovo\Anaconda3\lib\site-packages\numpy\core\_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\lenovo\Anaconda3\lib\site-packages\numpy\core\_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ...

# %%
a=sns.FacetGrid(data, col="Illness", row="Income", size=5)
a.map(plt.hist, "Age", bins=25)
a.add_legend()
plt.show()
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
a=sns.FacetGrid(data, row="Income", size=2)
a.map(sns.pointplot, "Illness", "Gender")
a.add_legend()
plt.show()
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\seaborn\axisgrid.py:715: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
